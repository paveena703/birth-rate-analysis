# %% [markdown]
# <a href="https://colab.research.google.com/github/paveena703/birth-rate-analysis/blob/main/exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
x=np.arange(1,11)
y=2*x+5
plt.title("Matplotlib demo")
plt.xlabel("x axis caption")
plt.ylabel("y axis caption")
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
dataframe=pd.DataFrame(
{
    "car":["BMW","Lexus","Audi","mustang","Bently","Jaguar"],
    "Reg_Price":[2000,2500,2800,3000,3200,3500,],
    "units":[100,120,150,170,180,20001]
}
)
plt.plot(dataframe["Reg_Price"],dataframe["units"])
plt.show()

# %%
# Install the data.table package (if not already installed)
install.packages("data.table")

# Load the data.table package
library("data.table")

# Create a data.table
dt_all <- data.table(x = rep(month.name[1:3], each = 3),
                     y = rep(c(1, 2, 3), times = 3),
                     z = rep(c(TRUE, FALSE, TRUE), each = 3))

# Display the first few rows of the data.table
head(dt_all)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-e3a6ee1e6bf7> in <cell line: 2>()
#       1 # Install the data.table package (if not already installed)
# ----> 2 install.packages("data.table")
#       3
#       4 # Load the data.table package
#       5 library("data.table")
#
# NameError: name 'install' is not defined

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
plt.rcParams.update({'figure.figsize':(10,7),'figure.dpi':120})
#import as dataframe

# %%
df=pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv',parse_dates=['date'])

# %%
df.head()
# Out:
#         date     value
# 0 1991-07-01  3.526591
# 1 1991-08-01  3.180891
# 2 1991-09-01  3.252221
# 3 1991-10-01  3.611003
# 4 1991-11-01  3.565869
